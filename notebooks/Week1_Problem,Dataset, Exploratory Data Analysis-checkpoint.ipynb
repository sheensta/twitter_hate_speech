# %% [markdown]
# # Twitter Hate Speech Analysis - Week 1
# ## Colin Green, Sean Zhang

# %% [markdown]
# ### Problem Statement
#
# Most individuals have encountered some form of hate speech or targeted harassment when participating on online social platforms such as social media, forums, or gaming. Unmoderated hate speech can have harmful consequences to its target and may cause anxiety, depression, or even suicide. Additionally, there are differences between hate speech and offensive language. Offensive language is merely speech that contains offensive words (such as quoting h*e or b*tch from song lyrics), while hate speech is targeted towards an individual or group, and is intended to be derogatory or insulting.
#
# Moderation through a simple rule-based approach can help identify speech with offensive language - for example, checking if speech contains strings that match with a list of banned words. However, a rule-based approach would have difficulty differentiating between offensive language and hate speech, as they both employ offensive words. Previous research was able to accurately classify either hate speech or offensive language from 'clean' text, with a 91% and 95% accuracy respectively, but had low accuracy when differentiating between hate speech and offensive language (61%). We plan to increase the accuracy between in successfully identifying instances of hate speech from offensive language.

# %% [markdown]
# ### Data Cleaning

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.options.display.width = 500
import nltk
import string
import re
from nltk.stem.porter import *

# %%
df = pd.read_csv('labeled_data.csv')
df = df[df['class'] != 2].iloc[:,1:]
df['class'] = df['class'].astype('category')

# %%
df.head()
# Out:
#    count  hate_speech  offensive_language  neither class                                              tweet
# 1      3            0                   3        0     1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...
# 2      3            0                   3        0     1  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...
# 3      3            0                   2        1     1  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...
# 4      6            0                   6        0     1  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...
# 5      3            1                   2        0     1  !!!!!!!!!!!!!!!!!!"@T_Madison_x: The shit just...

# %% [markdown]
# ### Data Exploration

# %%
height = (len(df[df['class']==0]), len(df[df['class']==1]))
bars = ('Hate speech', 'Offensive speech')
plt.bar(bars, height)
plt.title('Hate speech vs. Offensive speech count')
plt.show()
lenhatespeech = len(df[df['class']==0])
lenoffspeech = len(df[df['class']==1])

print('Hate speech count: ', lenhatespeech, '(', round(100*lenhatespeech/(lenhatespeech+lenoffspeech), 2), '%)')
print('Offensive speech count: ', lenoffspeech, '(', round(100*lenoffspeech/(lenhatespeech+lenoffspeech), 2), '%)')
# Out:
# Hate speech count:  1430 ( 6.94 %)
# Offensive speech count:  19190 ( 93.06 %)

# %%
#Data Preprocessing
import nltk
stopwords=stopwords = nltk.corpus.stopwords.words('english')
other_exclusions = ["#ff", "ff", "rt"]
stopwords.extend(other_exclusions)
stemmer = PorterStemmer()


def preprocess(text_string):
    """
    Accepts a text string and replaces:
    1) urls with URLHERE
    2) lots of whitespace with one instance
    3) mentions with MENTIONHERE

    This allows us to get standardized counts of urls and mentions
    Without caring about specific people mentioned
    """
    space_pattern = '\s+'
    giant_url_regex = ('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|'
        '[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    mention_regex = '@[\w\-]+'
    hashtag_regex = '#[\w\-]+'
    parsed_text = re.sub(space_pattern, ' ', text_string)
    parsed_text = re.sub(giant_url_regex, 'URLHERE', parsed_text)
    parsed_text = re.sub(mention_regex, 'MENTIONHERE', parsed_text)
    parsed_text = re.sub(hashtag_regex, 'HASHTAGHERE', parsed_text)
    return parsed_text

def tokenize(tweet):
    """Removes punctuation & excess whitespace, sets to lowercase,
    and stems tweets. Returns a list of stemmed tokens."""
    tweet = " ".join(re.split("[^a-zA-Z]*", tweet.lower())).strip()
    tokens = [stemmer.stem(t) for t in tweet.split()]
    return tokens

def basic_tokenize(tweet):
    tweet = " ".join(re.split("[^a-zA-Z.,!?]*", tweet.lower())).strip()
    return tweet.split()

# %%
df['tweet_clean'] = ''
for i, row in df.iterrows():
    df.at[i, 'tweet_clean'] = preprocess(row.tweet)

# %%
df['tweet_clean'].head()
# Out:
# 0    !!!!! rt mentionhere: boy dats cold...tyga dwn...
# 1    !!!!!!! rt mentionhere dawg!!!! rt mentionhere...
# 2    !!!!!!!!! rt mentionhere: mentionhere she look...
# 3    !!!!!!!!!!!!! rt mentionhere: the shit you hea...
# 4    !!!!!!!!!!!!!!!!!!"mentionhere: the shit just ...
# Name: tweet_clean, dtype: object

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
for i, row in df.iterrows():
    if(row['tweet_clean'] and len(str(row['tweet_clean'])) < 1000000):
        doc = nlp(str(row['tweet_clean']))
        adjectives = []
        nouns = []
        verbs = []
        lemmas = []
        
        for token in doc:
            lemmas.append(token.lemma_)
            if token.pos == 'ADJ':
                adjectives.append(token.lemma_)
            if token.pos_ == 'NOUN' or token.pos_ == 'PROPN':
                nouns.append(token.lemma_)
            if token.pos_ == 'VERB':
                verbs.append(token.lemma_)
        
        df.at[i, 'tweet_lemma'] = ' '.join(lemmas)
        df.at[i, 'tweet_nouns'] = ' '.join(nouns)
        df.at[i, 'tweet_adjectives'] = ' '.join(adjectives)
        df.at[i, 'tweet_verbs'] = ' '.join(verbs)
        df.at[i, 'tweet_nav'] = ' '.join(nouns + adjectives + verbs)
        df.at[i, 'num_tokens'] = len(lemmas)

# %%
df.head()
# Out:
#    index  count  hate_speech  offensive_language  neither class                                              tweet                                        tweet_clean                                        tweet_lemma                                        tweet_nouns tweet_adjectives        tweet_verbs                                          tweet_nav  num_tokens
# 0      1      3            0                   3        0     1  !!!!! RT @mleew17: boy dats cold...tyga dwn ba...  !!!!! rt mentionhere: boy dats cold...tyga dwn...  ! ! ! ! ! rt mentionhere : boy dats cold ... t...  rt mentionhere boy dats tyga dwn cuffin dat ho...                                      rt mentionhere boy dats tyga dwn cuffin dat ho...        25.0
# 1      2      3            0                   3        0     1  !!!!!!! RT @UrKindOfBrand Dawg!!!! RT @80sbaby...  !!!!!!! rt mentionhere dawg!!!! rt mentionhere...  ! ! ! ! ! ! ! rt mentionhere dawg ! ! ! ! rt m...      rt mentionhere dawg rt mentionhere bitch shit                      fuck start cry  rt mentionhere dawg rt mentionhere bitch shit ...        33.0
# 2      3      3            0                   2        1     1  !!!!!!!!! RT @C_G_Anderson: @viva_based she lo...  !!!!!!!!! rt mentionhere: mentionhere she look...  ! ! ! ! ! ! ! ! ! rt mentionhere : mentionhere...                  rt mentionhere mentionhere tranny                                look             rt mentionhere mentionhere tranny look        18.0
# 3      4      6            0                   6        0     1  !!!!!!!!!!!!! RT @ShenikaRoberts: The shit you...  !!!!!!!!!!!!! rt mentionhere: the shit you hea...  ! ! ! ! ! ! ! ! ! ! ! ! ! rt mentionhere : the...                    rt mentionhere shit faker bitch                   hear may may tell  rt mentionhere shit faker bitch hear may may tell        41.0
# 4      5      3            1                   2        0     1  !!!!!!!!!!!!!!!!!!"@T_Madison_x: The shit just...  !!!!!!!!!!!!!!!!!!"mentionhere: the shit just ...  ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! " mentionh...                               mentionhere shit hoe                     blow claim fuck               mentionhere shit hoe blow claim fuck        45.0

# %%
#Saving this to SQL database
import sqlite3
con = sqlite3.connect('twitter_hate.db')

drop = '''drop table tweets_nlp'''
with sqlite3.connect('twitter_hate.db') as con:
    con.execute(drop)
df.to_sql('tweets_nlp', con)
sql = """
SELECT * FROM tweets_nlp
"""
with sqlite3.connect('twitter_hate.db') as con:
    df = pd.read_sql_query(sql, con)

# %%
print('Data types:\n', df.dtypes)
print('Shape: ', df.shape)
print('Count:\n', df.count())
# Out:
# Data types:
#  level_0                 int64
# index                   int64
# count                   int64
# hate_speech             int64
# offensive_language      int64
# neither                 int64
# class                  object
# tweet                  object
# tweet_clean            object
# tweet_lemma            object
# tweet_nouns            object
# tweet_adjectives       object
# tweet_verbs            object
# tweet_nav              object
# num_tokens            float64
# dtype: object
# Shape:  (20620, 15)
# Count:
#  level_0               20620
# index                 20620
# count                 20620
# hate_speech           20620
# offensive_language    20620
# neither               20620
# class                 20620
# tweet                 20620
# tweet_clean           20620
# tweet_lemma           20620
# tweet_nouns           20620
# tweet_adjectives      20620
# tweet_verbs           20620
# tweet_nav             20620
# num_tokens            20620
# dtype: int64

# %%
plt.hist(df['num_tokens'])
print('Average number of tokens per tweet: ', round(df['num_tokens'].mean(), 2))
# Out:
# Average number of tokens per tweet:  16.72

# %%
#here we look at just the noun adjective and verbs
def my_tokenizer(text):
    return text.split() if text != None else []
tokens = df.tweet_nav.map(my_tokenizer).sum()
tokens[:20]
# Out:
# ['rt',
#  'mentionhere',
#  'boy',
#  'dats',
#  'tyga',
#  'dwn',
#  'cuffin',
#  'dat',
#  'hoe',
#  'place',
#  'rt',
#  'mentionhere',
#  'dawg',
#  'rt',
#  'mentionhere',
#  'bitch',
#  'shit',
#  'fuck',
#  'start',
#  'cry']

# %%
from collections import Counter

counter = Counter(tokens)
counter.most_common(20)
# Out:
# [('mentionhere', 14054),
#  ('bitch', 11110),
#  ('rt', 6257),
#  ('hoe', 4079),
#  ('get', 2103),
#  ('be', 2002),
#  ('pussy', 1580),
#  ('hashtaghere;mentionhere', 1473),
#  ('fuck', 1419),
#  ('go', 1360),
#  ('ass', 1258),
#  ('can', 1236),
#  ('nigga', 1231),
#  ('shit', 1229),
#  ('say', 919),
#  ('know', 836),
#  ('will', 791),
#  ('u', 761),
#  ('make', 714),
#  ('amp', 671)]

# %%
from spacy.lang.en.stop_words import STOP_WORDS
stopwords.append(STOP_WORDS)

def remove_stopwords(tokens):
    return [t for t in tokens if t not in stopwords]

counter = Counter(remove_stopwords(tokens))
counter.most_common(20)
# Out:
# [('mentionhere', 14054),
#  ('bitch', 11110),
#  ('hoe', 4079),
#  ('get', 2103),
#  ('pussy', 1580),
#  ('hashtaghere;mentionhere', 1473),
#  ('fuck', 1419),
#  ('go', 1360),
#  ('ass', 1258),
#  ('nigga', 1231),
#  ('shit', 1229),
#  ('say', 919),
#  ('know', 836),
#  ('u', 761),
#  ('make', 714),
#  ('amp', 671),
#  ('love', 661),
#  ('want', 638),
#  ('look', 627),
#  ('girl', 616)]

# %%
#MENTIONHERE, RT, HASHTAGHERE, URLHERE, HASTAGHERE;MENTIONHERE are not actual word features but rather imputed strings.
#amp likely refers to ampersand
#Let's remove these:

ignore_counter = ['mentionhere', 'rt', 'hashtaghere', 'urlhere', 'hashtaghere;mentionhere', 'amp']
for word in list(counter):
    if word in ignore_counter:
        del counter[word]
counter.most_common(500)
# Out:
# [('bitch', 11110),
#  ('hoe', 4079),
#  ('get', 2103),
#  ('pussy', 1580),
#  ('fuck', 1419),
#  ('go', 1360),
#  ('ass', 1258),
#  ('nigga', 1231),
#  ('shit', 1229),
#  ('say', 919),
#  ('know', 836),
#  ('u', 761),
#  ('make', 714),
#  ('love', 661),
#  ('want', 638),
#  ('look', 627),
#  ('girl', 616),
#  ('see', 589),
#  ('niggas', 588),
#  ('yo', 573),
#  ('lol', 566),
#  ('hashtaghere;&hashtaghere', 562),
#  ('think', 556),
#  ('call', 542),
#  ('talk', 508),
#  ('faggot', 508),
#  ('hate', 486),
#  ('tell', 485),
#  ('man', 471),
#  ('need', 468),
#  ('trash', 451),
#  ('come', 445),
#  ('time', 405),
#  ('take', 401),
#  ('let', 395),
#  ('would', 371),
#  ('eat', 371),
#  ('give', 359),
#  ('day', 345),
#  ('people', 343),
#  ('wit', 331),
#  ('dick', 330),
#  ('lmao', 324),
#  ('like', 323),
#  ('stop', 318),
#  ('wanna', 314),
#  ('try', 312),
#  ('bout', 311),
#  ('nigger', 307),
#  ('cunt', 286),
#  ('life', 284),
#  ('dat', 282),
#  ('fag', 273),
#  ('niggah', 265),
#  ('money', 263),
#  ('da', 263),
#  ('fuckin', 255),
#  ('lil', 254),
#  ('play', 244),
#  ('hashtaghere;&hashtaghere;&hashtaghere;&hashtaghere', 240),
#  ('put', 232),
#  ('hit', 231),
#  ('woman', 230),
#  ('keep', 224),
#  ('could', 223),
#  ('tweet', 223),
#  ('boy', 222),
#  ('feel', 219),
#  ('twitter', 212),
#  ('use', 200),
#  ('guy', 199),
#  ('start', 196),
#  ('tho', 196),
#  ('ask', 194),
#  ('work', 193),
#  ('thing', 191),
#  ('mean', 190),
#  ('ur', 188),
#  ('act', 185),
#  ('retard', 185),
#  ('friend', 180),
#  ('way', 179),
#  ('face', 179),
#  ('kill', 178),
#  ('tryna', 172),
#  ('head', 168),
#  ('watch', 168),
#  ('ya', 167),
#  ('turn', 167),
#  ('suck', 166),
#  ('shut', 166),
#  ('side', 166),
#  ('game', 164),
#  ('year', 162),
#  ('find', 161),
#  ('name', 161),
#  ('nicca', 152),
#  ('break', 151),
#  ('leave', 151),
#  ('show', 149),
#  ('today', 149),
#  ('school', 148),
#  ('dude', 147),
#  ('baby', 144),
#  ('beat', 143),
#  ('bro', 142),
#  ('gon', 139),
#  ('ghetto', 138),
#  ('care', 138),
#  ('fight', 136),
#  ('swear', 135),
#  ('hashtaghere;&hashtaghere;&hashtaghere', 133),
#  ('stay', 133),
#  ('one', 132),
#  ('night', 132),
#  ('trust', 130),
#  ('kid', 130),
#  ('lie', 130),
#  ('throw', 129),
#  ('bruh', 129),
#  ('bird', 126),
#  ("'d", 125),
#  ('buy', 125),
#  ('may', 122),
#  ('run', 122),
#  ('bring', 120),
#  ('wear', 120),
#  ('cut', 117),
#  ('cause', 117),
#  ('mom', 117),
#  ('wish', 117),
#  ('god', 116),
#  ('pic', 114),
#  ('lose', 114),
#  ('phone', 114),
#  ('die', 114),
#  ('nig', 113),
#  ('wait', 112),
#  ('hell', 112),
#  ('smh', 111),
#  ('text', 111),
#  ('house', 111),
#  ('thank', 110),
#  ('hashtaghere;&hashtaghere;&hashtaghere;&hashtaghere;&hashtaghere', 110),
#  ('niccas', 110),
#  ('walk', 109),
#  ('female', 109),
#  ('follow', 109),
#  ('sleep', 107),
#  ('live', 107),
#  ('hear', 106),
#  ('wtf', 105),
#  ('cry', 104),
#  ('car', 104),
#  ('son', 103),
#  ('sex', 103),
#  ('pay', 103),
#  ('catch', 101),
#  ('pull', 101),
#  ('stfu', 100),
#  ('tf', 100),
#  ('word', 100),
#  ('b', 97),
#  ('lot', 97),
#  ('hope', 96),
#  ('miss', 95),
#  ('dis', 95),
#  ('song', 95),
#  ('nah', 93),
#  ('ho', 93),
#  ('problem', 93),
#  ('dyke', 92),
#  ('send', 91),
#  ('cheat', 91),
#  ('hair', 91),
#  ('type', 90),
#  ('stand', 89),
#  ('smoke', 88),
#  ('chick', 88),
#  ('tonight', 87),
#  ('ion', 87),
#  ('_', 86),
#  ('sit', 85),
#  ('party', 85),
#  ('shoot', 85),
#  ('weed', 84),
#  ('drop', 83),
#  ('dog', 82),
#  ('lady', 82),
#  ('remember', 82),
#  ('meet', 81),
#  ('world', 81),
#  ('bet', 81),
#  ('fucking', 81),
#  ('job', 81),
#  ('change', 80),
#  ('queer', 80),
#  ('guess', 80),
#  ('yea', 79),
#  ('mind', 79),
#  ('pop', 79),
#  ('mouth', 79),
#  ('picture', 78),
#  ('move', 78),
#  ('bc', 77),
#  ('girlfriend', 77),
#  ('jus', 76),
#  ('hand', 76),
#  ('wake', 76),
#  ('date', 74),
#  ('pass', 74),
#  ('wife', 74),
#  ('redneck', 74),
#  ('body', 73),
#  ('forget', 73),
#  ('bitches', 73),
#  ('club', 73),
#  ('sound', 72),
#  ('bae', 72),
#  ('week', 72),
#  ('win', 71),
#  ('slap', 71),
#  ('white', 71),
#  ('laugh', 70),
#  ('listen', 70),
#  ('hurt', 69),
#  ('sell', 69),
#  ('back', 69),
#  ('birthday', 68),
#  ('ride', 68),
#  ('drive', 67),
#  ('music', 67),
#  ('grow', 67),
#  ('believe', 67),
#  ('line', 67),
#  ('point', 67),
#  ('boyfriend', 67),
#  ('chill', 66),
#  ('drink', 66),
#  ('end', 66),
#  ('post', 65),
#  ('ball', 65),
#  ('cracker', 65),
#  ('fall', 65),
#  ('smell', 65),
#  ('color', 65),
#  ('block', 65),
#  ('relationship', 64),
#  ('happen', 63),
#  ('eye', 63),
#  ('dress', 63),
#  ('fact', 62),
#  ('team', 62),
#  ('save', 61),
#  ('gettin', 61),
#  ('fat', 61),
#  ('ex', 61),
#  ('number', 61),
#  ('person', 61),
#  ('gay', 61),
#  ('must', 60),
#  ('outta', 60),
#  ('coon', 60),
#  ('got', 59),
#  ('monkey', 59),
#  ('reason', 59),
#  ('stick', 59),
#  ('talkin', 59),
#  ('blow', 58),
#  ('going', 58),
#  ('naw', 58),
#  ('wonder', 58),
#  ('respect', 57),
#  ('dad', 57),
#  ('idk', 57),
#  ('class', 57),
#  ('none', 56),
#  ('hold', 55),
#  ('speak', 55),
#  ('place', 54),
#  ('read', 54),
#  ('check', 54),
#  ('taste', 54),
#  ('kick', 54),
#  ('|', 54),
#  ('instagram', 54),
#  ('steal', 53),
#  ('ratchet', 53),
#  ('thot', 53),
#  ('heart', 53),
#  ('pick', 53),
#  ('cat', 52),
#  ('couple', 52),
#  ('treat', 52),
#  ('r', 52),
#  ('quit', 52),
#  ('dem', 52),
#  ('understand', 52),
#  ('voice', 51),
#  ('food', 51),
#  ('lmfao', 51),
#  ('nd', 51),
#  ('fan', 50),
#  ('street', 50),
#  ('hashtaghere;&hashtaghere;&hashtaghere;&hashtaghere;&hashtaghere;&hashtaghere',
#   50),
#  ('lookin', 50),
#  ('kiss', 49),
#  ('help', 49),
#  ('feeling', 49),
#  ('ppl', 48),
#  ('bed', 48),
#  ('nothing', 48),
#  ('attention', 48),
#  ('movie', 47),
#  ('month', 47),
#  ('booty', 47),
#  ('cop', 47),
#  ('self', 47),
#  ('%', 47),
#  ('brother', 46),
#  ('sum', 46),
#  ('water', 46),
#  ('yu', 46),
#  ('joke', 46),
#  ('hella', 45),
#  ('bunch', 45),
#  ('argue', 45),
#  ('niggaz', 45),
#  ('mother', 45),
#  ('twat', 45),
#  ('.', 44),
#  ('roll', 44),
#  ('karma', 44),
#  ('home', 44),
#  ('texte', 44),
#  ('haha', 44),
#  ('attitude', 44),
#  ('hang', 44),
#  ('suppose', 43),
#  ('room', 43),
#  ('morning', 43),
#  ('business', 42),
#  ('hood', 42),
#  ('bag', 42),
#  ('worry', 42),
#  ('become', 42),
#  ('finger', 42),
#  ('bullshit', 42),
#  ('deserve', 42),
#  ('realize', 42),
#  ('video', 41),
#  ('drug', 41),
#  ('nude', 41),
#  ('front', 41),
#  ('weekend', 41),
#  ('kno', 41),
#  ('family', 41),
#  ('rock', 41),
#  ('city', 41),
#  ('seem', 41),
#  ('lip', 40),
#  ('door', 40),
#  ('set', 40),
#  ('follower', 40),
#  ('homie', 40),
#  ('sister', 40),
#  ('w/', 40),
#  ('piss', 40),
#  ('folk', 40),
#  ('skin', 40),
#  ('complain', 40),
#  ('jump', 40),
#  ('chase', 39),
#  ('asshole', 39),
#  ('fun', 39),
#  ('dey', 39),
#  ('daddy', 38),
#  ('write', 38),
#  ('dream', 38),
#  ('state', 38),
#  ('rap', 38),
#  ('learn', 38),
#  ('dawg', 37),
#  ('finna', 37),
#  ('fucc', 37),
#  ('tomorrow', 37),
#  ('hahaha', 37),
#  ('answer', 37),
#  ('deal', 36),
#  ('lick', 36),
#  ('n', 36),
#  ('foot', 36),
#  ('mention', 36),
#  ('avi', 36),
#  ('boss', 36),
#  ('fire', 36),
#  ('hashtaghere;&hashtaghere;&hashtaghere;&hashtaghere;&hashtaghere;&hashtaghere;&hashtaghere',
#   36),
#  ('minute', 36),
#  ('knock', 36),
#  ('leg', 36),
#  ('shirt', 35),
#  ('dollar', 35),
#  ('smack', 35),
#  ('child', 35),
#  ('mama', 35),
#  ('mess', 35),
#  ('rest', 35),
#  ('truth', 35),
#  ('clothe', 35),
#  ('scare', 34),
#  ('expect', 34),
#  ('control', 34),
#  ('hoes', 34),
#  ('bear', 34),
#  ('mf', 34),
#  ('gun', 34),
#  ('hour', 34),
#  ('light', 34),
#  ('piece', 33),
#  ('damn', 33),
#  ('punch', 33),
#  ('order', 33),
#  ('slut', 33),
#  ('half', 33),
#  ('support', 33),
#  ('fly', 33),
#  ('country', 33),
#  ('blunt', 33),
#  ('claim', 32),
#  ('trick', 32),
#  ('scream', 32),
#  ('america', 32),
#  ('beer', 32),
#  ('hide', 32),
#  ('lmaooo', 32),
#  ('teach', 32),
#  ('beef', 32),
#  ('neck', 32),
#  ('negro', 32),
#  ('momma', 32),
#  ('cock', 32),
#  ('raise', 32),
#  ('doe', 32),
#  ('spend', 31),
#  ('jail', 31),
#  ('excuse', 31),
#  ('drake', 31),
#  ('handle', 31),
#  ('w', 31),
#  ('jesus', 31),
#  ('bust', 31),
#  ('rape', 31),
#  ('teacher', 30),
#  ('retweet', 30),
#  ('shoe', 30),
#  ('friday', 30),
#  ('dope', 30),
#  ('soul', 30),
#  ('tl', 30),
#  ('grade', 30),
#  ('new', 30),
#  ('hop', 30),
#  ('step', 30),
#  ('count', 30),
#  ('swag', 30),
#  ('g', 29),
#  ('halloween', 29),
#  ('cook', 29),
#  ('mine', 29),
#  ('butt', 29),
#  ('uncle', 29),
#  ('whip', 29),
#  ('nut', 29),
#  ('den', 29),
#  ('town', 29),
#  ('punk', 29),
#  ('tranny', 28),
#  ('cuff', 28),
#  ('k', 28),
#  ('beaner', 28),
#  ('wack', 28),
#  ('smile', 28),
#  ('chris', 28),
#  ('teabagger', 28),
#  ('part', 28),
#  ('trap', 28),
#  ('sayin', 28),
#  ('lay', 28),
#  ('j', 28),
#  ('idgaf', 28),
#  ('obama', 28),
#  ('bomb', 28),
#  ('level', 28),
#  ('mane', 27),
#  ('pimp', 27),
#  ('tv', 27),
#  ('kim', 27),
#  ('seat', 27),
#  ('thug', 27),
#  ('account', 27)]

# %%
#convert list to bargraph
freq_df = pd.DataFrame.from_records(counter.most_common(20), columns = ['token', 'count'])
freq_df.plot(kind = 'bar', x = 'token')

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
plt.rcParams['figure.dpi'] = 100

def wordcloud(counter):
    wc = WordCloud(width = 1200, height = 800, background_color = 'white', max_words = 200)
    wc.generate_from_frequencies(counter)

    fig = plt.figure(figsize=(6,4))
    plt.imshow(wc, interpolation = 'bilinear')
    plt.axis('off')
    plt.show()

# %%
wordcloud(counter)
